# %% [markdown]
# # Data Mining and Wrangling - `worth` _Salary Estimator_

# %% [markdown]
# ### Placement details from Brototype Office

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from fuzzywuzzy import fuzz, process

# %%
# Reading the dataset
path_1 = 'data/raw_data/brototype_office/placement_details.csv'

office_data = pd.read_csv(path_1, index_col=0)
office_data.head()
# Out:
#                        Name                                 Domain  Batch  \
# Sl No.
# 1                    Fais M    Web Development Using Python Django  BCK01
# 2            Hashim Rasheed  Web Development Using Node.js Express  BCK01
# 3           Mohammed Arshad    Web Development Using Python Django  BCK01
# 4       Muhammed Musthafa P                             MERN Stack  BCK01
# 5       Muhammed Shafeerali    Web Development Using Python Django  BCK01
#
#                        Placed Company         Designation CTC (LPA)
# Sl No.
# 1                VNC Digital Services   Software Engineer      3.00
# 2       Emstell Technology Consulting   Software Engineer      2.16
# 3                      Creative Panda   Node JS Developer      2.40
# 4                                   -  Software Developer         -
# 5                            ActionFi   Software Engineer      2.40

# %%
office_data.shape
# Out:
# (670, 6)

# %%
office_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 670 entries, 1 to 670
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            670 non-null    object
#  1   Domain          670 non-null    object
#  2   Batch           670 non-null    object
#  3   Placed Company  670 non-null    object
#  4   Designation     670 non-null    object
#  5   CTC (LPA)       670 non-null    object
# dtypes: object(6)
# memory usage: 36.6+ KB

# %% [markdown]
# ### Data from google form survey

# %%
# Reading the dataset
path_2 = 'data/raw_data/gform/gform_responses.csv'

gform = pd.read_csv(path_2)
gform.head()
# Out:
#                         Timestamp              Name  Age  \
# 0  2023/05/02 2:43:35 PM GMT+5:30      Nihal Avulan   19
# 1  2023/05/02 2:44:53 PM GMT+5:30  Ahmad Shabeer K    23
# 2  2023/05/02 2:45:16 PM GMT+5:30  Ahammed Nihal PT   21
# 3  2023/05/02 2:45:16 PM GMT+5:30             Arjun   22
# 4  2023/05/02 2:46:59 PM GMT+5:30            Mishal   25
#
#   Which domain you chose in Brototype?  \
# 0                           MERN Stack
# 1                           MEAN Stack
# 2                           MERN Stack
# 3                           MERN Stack
# 4                           MEAN Stack
#
#   Currently working as? (eg:- React Developer) Do you have a Degree/Diploma?  \
# 0                         Full stack engineer                      No Degree
# 1                           Angular Developer                      No Degree
# 2                               Mern developer                        Degree
# 3                         MERN Stack developer                     No Degree
# 4                           Software Engineer                         Degree
#
#   Are you from Computer Science background?  \
# 0                                        No
# 1                                        No
# 2                                       Yes
# 3                                        No
# 4                                        No
#
#   Did you have any experience before joining Brototype?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    How much time did you spend at the office on average in a day? (Hour)  \
# 0                                               16.0
# 1                                               12.0
# 2                                               10.0
# 3                                               10.0
# 4                                                7.5
#
#   Did you utilize office space in Holidays (Sunday, Public Holidays, etc.)  \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    How many week backs have you received?  \
# 0                                       3
# 1                                       4
# 2                                       4
# 3                                       0
# 4                                       3
#
#   Current working place? (eg:- Bangalore, Use WFH for work from home)  \
# 0                                             Office
# 1                                            Manjeri
# 2                                            On site
# 3                                          Bangalore
# 4                                                WFH
#
#   Technical Skills acquired? (Type in as React, Node, Html, CSS, etc..)  \
# 0  React,node,js,typescript,expresses,mongodb,htm...
# 1  Angular, Node JS, Express JS, HTML, CSS, Linux...
# 2  React, Node js, html, css, bootstrap, git, Ms ...
# 3  React, Node, HTML, CSS, TailwindCSS, SCSS, Mon...
# 4  Angular, Express, Node, javascript, MongoDB, H...
#
#   Did you complete 6 months?  \
# 0                        Yes
# 1                        Yes
# 2                        Yes
# 3                         No
# 4                         No
#
#   TOI Score (Type "Not Applicable" if you didn't receive any score)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    The Salary you got placed in Lakhs? (eg:- 6)
# 0                                           9.0
# 1                                           4.7
# 2                                           6.0
# 3                                           4.2
# 4                                           4.5

# %%
gform.shape
# Out:
# (30, 16)

# %%
print(gform.columns)
# Out:
# Index(['Timestamp', 'Name', 'Age', 'Which domain you chose in Brototype?',
#        'Currently working as? (eg:- React Developer)',
#        'Do you have a Degree/Diploma?',
#        'Are you from Computer Science background?',
#        'Did you have any experience before joining Brototype?',
#        'How much time did you spend at the office on average in a day? (Hour)',
#        'Did you utilize office space in Holidays (Sunday, Public Holidays, etc.)',
#        'How many week backs have you received?',
#        'Current working place? (eg:- Bangalore, Use WFH for work from home)',
#        'Technical Skills acquired? (Type in as React, Node, Html, CSS, etc..)',
#        'Did you complete 6 months?',
#        'TOI Score (Type "Not Applicable" if you didn't receive any score)',
#        'The Salary you got placed in Lakhs? (eg:- 6)'],
#       dtype='object')

# %%
gform.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 16 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Timestamp                                                                 30 non-null     object
#  1   Name                                                                      30 non-null     object
#  2   Age                                                                       30 non-null     int64
#  3   Which domain you chose in Brototype?                                      30 non-null     object
#  4   Currently working as? (eg:- React Developer)                              30 non-null     object
#  5   Do you have a Degree/Diploma?                                             30 non-null     object
#  6   Are you from Computer Science background?                                 30 non-null     object
#  7   Did you have any experience before joining Brototype?                     30 non-null     object
#  8   How much time did you spend at the office on average in a day? (Hour)     30 non-null     float64
#  9   Did you utilize office space in Holidays (Sunday, Public Holidays, etc.)  30 non-null     object
#  10  How many week backs have you received?                                    30 non-null     int64
#  11  Current working place? (eg:- Bangalore, Use WFH for work from home)       30 non-null     object
#  12  Technical Skills acquired? (Type in as React, Node, Html, CSS, etc..)     30 non-null     object
#  13  Did you complete 6 months?                                                30 non-null     object
#  14  TOI Score (Type "Not Applicable" if you didn't receive any score)         4 non-null      object
#  15  The Salary you got placed in Lakhs? (eg:- 6)                              30 non-null     float64
# dtypes: float64(2), int64(2), object(12)
# memory usage: 3.9+ KB

# %%
# Removing unnecessry columns
gform = gform.iloc[:, 1:]
gform.head()
# Out:
#                Name  Age Which domain you chose in Brototype?  \
# 0      Nihal Avulan   19                           MERN Stack
# 1  Ahmad Shabeer K    23                           MEAN Stack
# 2  Ahammed Nihal PT   21                           MERN Stack
# 3             Arjun   22                           MERN Stack
# 4            Mishal   25                           MEAN Stack
#
#   Currently working as? (eg:- React Developer) Do you have a Degree/Diploma?  \
# 0                         Full stack engineer                      No Degree
# 1                           Angular Developer                      No Degree
# 2                               Mern developer                        Degree
# 3                         MERN Stack developer                     No Degree
# 4                           Software Engineer                         Degree
#
#   Are you from Computer Science background?  \
# 0                                        No
# 1                                        No
# 2                                       Yes
# 3                                        No
# 4                                        No
#
#   Did you have any experience before joining Brototype?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    How much time did you spend at the office on average in a day? (Hour)  \
# 0                                               16.0
# 1                                               12.0
# 2                                               10.0
# 3                                               10.0
# 4                                                7.5
#
#   Did you utilize office space in Holidays (Sunday, Public Holidays, etc.)  \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    How many week backs have you received?  \
# 0                                       3
# 1                                       4
# 2                                       4
# 3                                       0
# 4                                       3
#
#   Current working place? (eg:- Bangalore, Use WFH for work from home)  \
# 0                                             Office
# 1                                            Manjeri
# 2                                            On site
# 3                                          Bangalore
# 4                                                WFH
#
#   Technical Skills acquired? (Type in as React, Node, Html, CSS, etc..)  \
# 0  React,node,js,typescript,expresses,mongodb,htm...
# 1  Angular, Node JS, Express JS, HTML, CSS, Linux...
# 2  React, Node js, html, css, bootstrap, git, Ms ...
# 3  React, Node, HTML, CSS, TailwindCSS, SCSS, Mon...
# 4  Angular, Express, Node, javascript, MongoDB, H...
#
#   Did you complete 6 months?  \
# 0                        Yes
# 1                        Yes
# 2                        Yes
# 3                         No
# 4                         No
#
#   TOI Score (Type "Not Applicable" if you didn't receive any score)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    The Salary you got placed in Lakhs? (eg:- 6)
# 0                                           9.0
# 1                                           4.7
# 2                                           6.0
# 3                                           4.2
# 4                                           4.5

# %%
# Renaming column names
cols = ['name','age', 'domain', 'current_job', 'degree', 'cs_bg', 'experience', 'avg_time', 'holidays', 'week_back', 'city', 'skills', 'graduated', 'toi', 'salary']
gform.columns = cols
gform.head()
# Out:
#                name  age      domain           current_job     degree cs_bg  \
# 0      Nihal Avulan   19  MERN Stack  Full stack engineer   No Degree    No
# 1  Ahmad Shabeer K    23  MEAN Stack    Angular Developer   No Degree    No
# 2  Ahammed Nihal PT   21  MERN Stack        Mern developer     Degree   Yes
# 3             Arjun   22  MERN Stack  MERN Stack developer  No Degree    No
# 4            Mishal   25  MEAN Stack    Software Engineer      Degree    No
#
#   experience  avg_time holidays  week_back       city  \
# 0         No      16.0      Yes          3     Office
# 1         No      12.0      Yes          4    Manjeri
# 2         No      10.0       No          4    On site
# 3         No      10.0       No          0  Bangalore
# 4         No       7.5       No          3        WFH
#
#                                               skills graduated  toi  salary
# 0  React,node,js,typescript,expresses,mongodb,htm...       Yes  NaN     9.0
# 1  Angular, Node JS, Express JS, HTML, CSS, Linux...       Yes  NaN     4.7
# 2  React, Node js, html, css, bootstrap, git, Ms ...       Yes  NaN     6.0
# 3  React, Node, HTML, CSS, TailwindCSS, SCSS, Mon...        No  NaN     4.2
# 4  Angular, Express, Node, javascript, MongoDB, H...        No  NaN     4.5

# %% [markdown]
# ### Creating a single Dataframe by combining data from `office dataframe` and `gform dataframe`

# %%
### Create a new DataFrame to store the combined data
combined_df = office_data.copy()

# Iterate over the names in dataframe_1
for i, name_df1 in enumerate(office_data['Name']):
    best_match = process.extractOne(name_df1, gform['name'])
    if best_match[1] > 90:  # Set a threshold for similarity score
        name_df2 = best_match[0]
        data_df2 = gform[gform['name'] == name_df2]
        data_df2 = data_df2.drop(columns=['name'])  # Remove the 'name' column from dataframe_2

        # Assign values individually to each cell using .at accessor
        for col in data_df2.columns:
            combined_df.at[i, col] = data_df2[col].values[0]
    else:
        # Assign null values for the columns from dataframe_2
        for col in gform.columns[1:]:  # Exclude the 'name' column
            combined_df.at[i, col] = None

# %%
# Create a new DataFrame to store the combined data
combined_df = office_data.copy()

# Iterate over the names in office_data
for i, name_df1 in enumerate(office_data['Name']):
    best_match = process.extractOne(name_df1, gform['name'])
    if best_match[1] > 90:  # Set a threshold for similarity score
        name_df2 = best_match[0]
        data_df2 = gform[gform['name'] == name_df2]
        data_df2 = data_df2.drop(columns=['name'])  # Remove the 'name' column from data_df2

        # Find the matching record in data_df2 based on the CTC column
        matching_record = data_df2[data_df2['salary'] == office_data.at[i, 'CTC (LPA)']]

        if not matching_record.empty:
            # Assign values from matching_record to combined_df
            for col in matching_record.columns:
                if col != 'salary':  # Skip assigning the 'salary' column
                    combined_df.at[i, col] = matching_record[col].values[0]
    else:
        # Assign null values for the columns from data_df2
        for col in gform.columns[1:]:  # Exclude the 'name' column
            combined_df.at[i, col] = None

# %%
combined_df.head()
# Out:
#                        Name                                 Domain  Batch  \
# Sl No.
# 1                    Fais M    Web Development Using Python Django  BCK01
# 2            Hashim Rasheed  Web Development Using Node.js Express  BCK01
# 3           Mohammed Arshad    Web Development Using Python Django  BCK01
# 4       Muhammed Musthafa P                             MERN Stack  BCK01
# 5       Muhammed Shafeerali    Web Development Using Python Django  BCK01
#
#                        Placed Company         Designation CTC (LPA)  age  \
# Sl No.
# 1                VNC Digital Services   Software Engineer      3.00  NaN
# 2       Emstell Technology Consulting   Software Engineer      2.16  NaN
# 3                      Creative Panda   Node JS Developer      2.40  NaN
# 4                                   -  Software Developer         -  NaN
# 5                            ActionFi   Software Engineer      2.40  NaN
#
#         domain  current_job  degree  cs_bg  experience  avg_time  holidays  \
# Sl No.
# 1          NaN          NaN     NaN    NaN         NaN       NaN       NaN
# 2          NaN          NaN     NaN    NaN         NaN       NaN       NaN
# 3          NaN          NaN     NaN    NaN         NaN       NaN       NaN
# 4          NaN          NaN     NaN    NaN         NaN       NaN       NaN
# 5          NaN          NaN     NaN    NaN         NaN       NaN       NaN
#
#         week_back  city  skills  graduated  toi  salary
# Sl No.
# 1             NaN   NaN     NaN        NaN  NaN     NaN
# 2             NaN   NaN     NaN        NaN  NaN     NaN
# 3             NaN   NaN     NaN        NaN  NaN     NaN
# 4             NaN   NaN     NaN        NaN  NaN     NaN
# 5             NaN   NaN     NaN        NaN  NaN     NaN

# %%
mask = combined_df['salary'].notna()

combined_df.loc[mask, ['Name', 'salary', 'CTC (LPA)']]
# Out:
# Empty DataFrame
# Columns: [Name, salary, CTC (LPA)]
# Index: []

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 671 entries, 1 to 0
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            670 non-null    object
#  1   Domain          670 non-null    object
#  2   Batch           670 non-null    object
#  3   Placed Company  670 non-null    object
#  4   Designation     670 non-null    object
#  5   CTC (LPA)       670 non-null    object
#  6   age             0 non-null      float64
#  7   domain          0 non-null      float64
#  8   current_job     0 non-null      float64
#  9   degree          0 non-null      float64
#  10  cs_bg           0 non-null      float64
#  11  experience      0 non-null      float64
#  12  avg_time        0 non-null      float64
#  13  holidays        0 non-null      float64
#  14  week_back       0 non-null      float64
#  15  city            0 non-null      float64
#  16  skills          0 non-null      float64
#  17  graduated       0 non-null      float64
#  18  toi             0 non-null      float64
#  19  salary          0 non-null      float64
# dtypes: float64(14), object(6)
# memory usage: 126.2+ KB

# %%
combined_df[combined_df['Name'].isna()]
# Out:
#        Name Domain Batch Placed Company Designation CTC (LPA)  age domain  \
# Sl No.
# 0       NaN    NaN   NaN            NaN         NaN       NaN  NaN    NaN
#
#        current_job degree cs_bg experience  avg_time holidays  week_back city  \
# Sl No.
# 0              NaN    NaN   NaN        NaN       NaN      NaN        NaN  NaN
#
#        skills graduated  toi  salary
# Sl No.
# 0         NaN       NaN  NaN     NaN

# %%
combined_df = combined_df.dropna(subset=['Name'])
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 670 entries, 1 to 670
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            670 non-null    object
#  1   Domain          670 non-null    object
#  2   Batch           670 non-null    object
#  3   Placed Company  670 non-null    object
#  4   Designation     670 non-null    object
#  5   CTC (LPA)       670 non-null    object
#  6   age             26 non-null     float64
#  7   domain          26 non-null     object
#  8   current_job     26 non-null     object
#  9   degree          26 non-null     object
#  10  cs_bg           26 non-null     object
#  11  experience      26 non-null     object
#  12  avg_time        26 non-null     float64
#  13  holidays        26 non-null     object
#  14  week_back       26 non-null     float64
#  15  city            26 non-null     object
#  16  skills          26 non-null     object
#  17  graduated       26 non-null     object
#  18  toi             2 non-null      object
#  19  salary          26 non-null     float64
# dtypes: float64(4), object(16)
# memory usage: 109.9+ KB

# %% [markdown]
# ### Saving df to a csv File

# %% [markdown]
# combined_df.to_csv('data/combined_data/raw_data.csv', index=False)
